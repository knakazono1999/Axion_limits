# %%
from PlotFuncs import *
import matplotlib.ticker as ticker
# %matplotlib inline

# plt.rcParams['font.family']= 'sans-serif'
# plt.rcParams['font.sans-serif'] = ['Arial']
# #plt.rcParams['mathtext.fontset'] = 'cm' # Computer Modern (TeXのフォント)
# plt.rcParams['font.size'] = 16 # 論文なら10-12ptくらいが適正


m_min = 1e-5
m_max = 0.0001


HAYSTAC_col = 'darkgray'
CAPP_col = 'darkgray'
QUAX_col = 'darkgray'
ADMX_col = 'darkgray'
FAST_col = 'darkgray'
BRASS_col='darkgray'
SRF_col='darkgray'
QUALIPHIDE_col = 'darkgray'
BREAD_col = 'darkgray'

fig,ax = DarkPhoton.FigSetup(m_min=m_min,m_max=m_max,chi_min=1e-15,chi_max=1e-9,\
                  FrequencyLabels=False,FrequencyAxis=True,upper_tickdir='in',\
                  Shape='Custom',width=20,height=14,f_rescale=1e9,tfs=31,lfs=35)

# === ここに追加 ===
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']

# 数式（軸の指数表記など）もArialを使うように設定
plt.rcParams['mathtext.fontset'] = 'custom'
plt.rcParams['mathtext.rm'] = 'Arial'
plt.rcParams['mathtext.it'] = 'Arial:italic'
plt.rcParams['mathtext.bf'] = 'Arial:bold'

plt.title(r'Frequency [GHz]',ha='center',fontsize=35,pad=20)


DarkPhoton.DarkMatter(ax,text_on=False,Witte_col='gray',Caputo_col='gray',Arias_col='gray',lw=0)
DarkPhoton.StellarBounds(ax,text_on=False)



DarkPhoton.Tokyo(ax,text_on=False,col='darkgray',lw=0)
DarkPhoton.SHUKET(ax,text_on=False,edge_on=True,col='darkgray',lw=0)
DarkPhoton.DarkEfield(ax,text_on=False,edge_on=True,col='darkgray',lw=0)
DarkPhoton.WISPDMX(ax,text_on=False,edge_on=True,col='darkgray',lw=0)
DarkPhoton.SQuAD(ax,text_on=False,col='darkgray',point_on=False,lw=0)
DarkPhoton.ORPHEUS(ax,text_on=False,col='darkgray',edge_on=True,lw=0)
DarkPhoton.DOSUE(ax,text_on=False,col='darkgray',edge_on=True,lw=0)
DarkPhoton.FAST(ax,text_on=False,col=FAST_col,edge_on=True,lw=0)
DarkPhoton.SQMS(ax,text_on=False,col=SRF_col,lw=0)
DarkPhoton.QUALIPHIDE(ax,text_on=False,col=QUALIPHIDE_col,edge_on=True,lw=0)
DarkPhoton.LOFAR(ax,text_on=False,col=FAST_col,edge_on=True,lw=0)
DarkPhoton.BRASS(ax,text_on=False,col=BRASS_col,edge_on=True,lw=0)
DarkPhoton.SHANHE(ax,text_on=False,col=SRF_col,edge_on=True,lw=0)
DarkPhoton.GigaBREAD(ax,text_on=False,col=BREAD_col,edge_on=True,lw=0)
DarkPhoton.MADMAX(ax,text_on=False,col='darkgray',edge_on=True,lw=0)

y2 = ax.get_ylim()[1]




# ADMX
dat = loadtxt("limit_data/DarkPhoton/Rescaled/ADMX.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1,lw=0)
dat = loadtxt("limit_data/DarkPhoton/Rescaled/ADMX2018.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1,lw=0)
dat = loadtxt("limit_data/DarkPhoton/Rescaled/ADMX2019_1.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1,lw=0)
dat = loadtxt("limit_data/DarkPhoton/Rescaled/ADMX2019_2.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1,lw=0)
dat = loadtxt("limit_data/DarkPhoton/Rescaled/ADMX2021.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1,lw=0)
dat = loadtxt("limit_data/DarkPhoton/Rescaled/ADMX2024.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=ADMX_col,zorder=0.1,lw=0)
dat = loadtxt("limit_data/DarkPhoton/Rescaled/ADMX_Sidecar.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor=ADMX_col,facecolor=ADMX_col,zorder=0.1,lw=0)

# HAYSTAC
dat = loadtxt("limit_data/DarkPhoton/Rescaled/HAYSTAC_PhaseI.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=HAYSTAC_col,zorder=0.1,lw=0)
dat = loadtxt("limit_data/DarkPhoton/Rescaled/HAYSTAC_PhaseII_ab.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=HAYSTAC_col,zorder=0.1,lw=0)
dat = loadtxt("limit_data/DarkPhoton/Rescaled/HAYSTAC_PhaseII_cd.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=HAYSTAC_col,zorder=0.1,lw=0)


# CAPP
dat = loadtxt("limit_data/DarkPhoton/Rescaled/CAPP-1.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.1,lw=0)
dat = loadtxt("limit_data/DarkPhoton/Rescaled/CAPP-2.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.1,lw=0)
dat = loadtxt("limit_data/DarkPhoton/Rescaled/CAPP-3.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.1,lw=0)
dat = loadtxt("limit_data/DarkPhoton/Rescaled/CAPP-4.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.1,lw=0)
dat = loadtxt("limit_data/DarkPhoton/Rescaled/CAPP-5.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.1,lw=0)
dat = loadtxt("limit_data/DarkPhoton/Rescaled/CAPP-6.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.1,lw=0)
dat = loadtxt("limit_data/DarkPhoton/Rescaled/CAPP-7.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.1,lw=0)
dat = loadtxt("limit_data/DarkPhoton/Rescaled/CAPP-8.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.1,lw=0)
dat = loadtxt("limit_data/DarkPhoton/Rescaled/CAPP-MAX.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.1,lw=0)
dat = loadtxt("limit_data/DarkPhoton/Rescaled/CAST-CAPP.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.1,lw=0)

dat = loadtxt("limit_data/DarkPhoton/Rescaled/TASEH.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor='darkgray',zorder=0.1,lw=0)

dat = loadtxt("limit_data/DarkPhoton/Rescaled/ORGAN-1a.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.21,lw=0)
dat = loadtxt("limit_data/DarkPhoton/Rescaled/ORGAN-1b.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.21,lw=0)
dat = loadtxt("limit_data/DarkPhoton/Rescaled/ORGAN-Q.txt")
plt.fill_between(dat[:,0],dat[:,1],y2=y2,edgecolor='k',facecolor=CAPP_col,zorder=0.21,lw=0)


dat = loadtxt("limit_data/DarkPhoton/Rescaled/QUAX.txt")
dat[0,1] = 1e0
plt.plot(dat[:,0],dat[:,1],zorder=0.2,color=QUAX_col,lw=1)
dat = loadtxt("limit_data/DarkPhoton/Rescaled/QUAX2.txt")
dat[0,1] = 1e0
plt.plot(dat[:,0],dat[:,1],zorder=0.2,color=QUAX_col,lw=1)
dat = loadtxt("limit_data/DarkPhoton/Rescaled/QUAX4.txt")
dat[0,1] = 1e0
plt.plot(dat[:,0],dat[:,1],zorder=0.2,color=QUAX_col,lw=1)
dat = loadtxt("limit_data/DarkPhoton/Rescaled/QUAX5.txt")
plt.plot(dat[:,0],dat[:,1],zorder=0.2,color=QUAX_col,lw=1)


SUPAX_col = 'darkgray'
dat = loadtxt("limit_data/DarkPhoton/Rescaled/SUPAX.txt")
dat[0,1] = 1e0
plt.plot(dat[:,0],dat[:,1],zorder=0.2,color=SUPAX_col,lw=1)

APEX_col = 'darkgray'
dat = loadtxt("limit_data/DarkPhoton/Rescaled/APEX.txt")
dat[0,1] = 1e0
plt.plot(dat[:,0],dat[:,1],zorder=0.2,color=APEX_col,lw=1)

dat = loadtxt("/Users/kn/quantum_data/2410_measurement/DMdata/lambshift/Analysis/202512181501/DarQ_Lamb_temp_limit_202512181501.txt")
dat[0,1] = 1e0
plt.plot(dat[:,0],dat[:,1],zorder=0.2,color='orange',lw=2)

# # text labels
# plt.text(2e-6,3.8e-11,r'{\bf Cosmology}',color='w',fontsize=43,rotation=3.6,path_effects=line_background(2,'k'))
# plt.text(6e-7,1.7e-12,r'{\bf WISPDMX}',color='w',path_effects=line_background(1.5,'k'))
# plt.text(1.99e-7,8e-13,r'{\bf LOFAR}',color='w',fontsize=18,ha='center',path_effects=line_background(1,'k'))
# plt.text(1.99e-7,4e-13,r'{\bf (Sun)}',color='w',fontsize=18,ha='center',path_effects=line_background(1,'k'))
# plt.text(3.9e-7,0.5e-14,r'{\bf Dark E-field}',color='ForestGreen',fontsize=27,path_effects=line_background(1,'k'))
# plt.text(2.5e-6,0.08e-14,r'{\bf ADMX}',color=ADMX_col,fontsize=22,path_effects=line_background(1,'k'))
# plt.text(2.99e-5,1.9e-14,r'{\bf ADMX-Sidecar}',color=ADMX_col,fontsize=14,rotation=-90)
# plt.text(2.75e-5,3.3e-13,r'{\bf APEX}',color=APEX_col,fontsize=14,rotation=90)
# plt.text(7e-6,0.5e-12,r'{\bf CAPP-1}',color=CAPP_col,fontsize=18,rotation=90)
# plt.text(1.18e-5,0.5e-12,r'{\bf CAPP-2}',color=CAPP_col,fontsize=18,rotation=90)
# plt.text(0.97e-5,0.01e-12,r'{\bf CAPP-3}',color=CAPP_col,fontsize=18,rotation=90)
# plt.text(8.5e-6,0.5e-12,r'{\bf CAPP-5}',color=CAPP_col,fontsize=18,rotation=90)
# plt.text(4.78e-6,0.2e-13,r'{\bf CAPP-MAX}',color=CAPP_col,fontsize=17,rotation=-90)

# plt.text(19e-6*1.01,0.32e-14,r'{\bf CAPP-7}',color=CAPP_col,fontsize=14,rotation=90)
# plt.text(21e-6*1.01,0.23e-14,r'{\bf CAPP-8}',color=CAPP_col,fontsize=14,rotation=90)

# plt.text(2e-5,0.6e-12,r'{\bf CAST-CAPP}',color='w',fontsize=15,rotation=90)
# plt.text(5.8e-5,0.8e-12,r'{\bf ORGAN}',color=CAPP_col,fontsize=18,rotation=90)
# plt.text(3.02e-5,1.7e-12,r'{\bf QUALIPHIDE}',color=QUALIPHIDE_col,fontsize=15,rotation=-90)
# plt.text(3.35e-5,1.3e-13,r'{\bf SUPAX}',color=SUPAX_col,fontsize=12,rotation=-90)
# plt.text(4.55e-6,0.88e-11,r'{\bf FAST}',color='w',fontsize=20,rotation=0,path_effects=line_background(1,'k'))
# plt.text(1.98e-5,6.5e-14,r'{\bf TASEH}',color='darkred',fontsize=13,rotation=-90)
# plt.text(2.3e-5,0.08e-12/60,r'{\bf HAYSTAC}',color=HAYSTAC_col,fontsize=14,rotation=90)
# plt.text(1.58e-5,0.08e-12,r'{\bf HAYSTAC}',color=HAYSTAC_col,fontsize=14,rotation=90)
# plt.text(5.7e-6,0.65e-14,r'{\bf SQMS + SHANHE',fontsize=12,color='#02734b',rotation=-90,rotation_mode='anchor',ha='center',va='center',clip_on=True)
# plt.text(2.5e-5,3e-14,r'{\bf ORGAN}',color=CAPP_col,fontsize=14,rotation=-90)
# plt.text(2.5e-5,2e-15,r'{\bf SQuAD}',color='g',fontsize=15,rotation=-90)
# plt.text(1.9e-5,8e-11,r'{\bf SHUKET}',color='w',fontsize=20,rotation=9,path_effects=line_background(1,'k'))
# plt.text(3.75e-5,4.5e-12,r'{\bf QUAX}',color=QUAX_col,fontsize=18,rotation=-90)
# plt.text(6.5e-5,0.025e-13,r'{\bf ORPHEUS}',color='darkgreen',fontsize=18,rotation=90)
# plt.text(5.1e-5,1.2e-13,r'{\bf BRASS}',color='w',fontsize=14,rotation=90,path_effects=line_background(1,'k'))
# plt.text(8.5e-5,7e-13,r'{\bf MADMAX}',color='seagreen',fontsize=18,rotation=-90)
# plt.text(7.45e-5,2e-10,r'{\bf DOSUE}',color='w',fontsize=13,rotation=0,path_effects=line_background(1,'k'))
# plt.text(4.5e-5,2.3e-12,r'{\bf GigaBREAD}',color='w',fontsize=16,rotation=-90,path_effects=line_background(1,'k'))

# plt.gcf().text(0.14,0.16,r'$\rho_{\rm DM} = 0.45$ GeV cm$^{-3}$',fontsize=30,ha='left')

# CAPP-4 and HAYSTAC_2022 currently not shown to reduce severe clutter around 5 GHz


# ========= ここからインセット =========
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset

# メイン軸 ax の上に小さい軸を作成（位置やサイズは調整して下さい）
axins = inset_axes(
    ax,
    width="50%",   # 親axに対する幅 (％)
    height="50%",  # 親axに対する高さ (％)
    loc="upper right",  # 'upper left', 'lower left', なども可
    borderpad=1.0
)

ax.set_xscale('linear')
# 軸スケールをメインと合わせる（対数軸なら必須）
axins.set_xscale('linear')
axins.set_yscale('log')

# ズームしたい範囲を指定（例：m ~ 2e-5〜4e-5, chi ~ 1e-15〜1e-11）
x1, x2 = 3.6125e-5, 3.619e-5
y1, y2_ = 1.0e-13, 1.0e-10
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2_)

# インセットには DarQ-Lamb のカーブだけ重ね描き（必要なら他も）
dat = loadtxt("/Users/kn/quantum_data/2410_measurement/DMdata/lambshift/Analysis/202512181501/DarQ_Lamb_temp_limit_202512181501.txt")
dat[0,1] = 1e0
axins.fill_between(dat[:,0], dat[:,1],y2=y2, color='orange', lw=2,label=r"$\langle \cos^2{\theta}\rangle=1/3$")

dat = loadtxt("/Users/kn/quantum_data/2410_measurement/DMdata/lambshift/Analysis/202512181501/DarQ_Lamb_temp_limit_202512181501_certain_direction.txt")
dat[0,1] = 1e0
axins.fill_between(dat[:,0], dat[:,1],y2=y2, color='C0', lw=2,label=r"$\langle \cos^2{\theta} \rangle=0.025$")

ax.ticklabel_format(style='sci', axis='x', scilimits=(-6, -6), useMathText=True)
axins.ticklabel_format(style='sci', axis='x', scilimits=(-6, -6), useMathText=True)
plt.legend(fontsize=24,loc='lower right',frameon=True)

def to_micro(x, pos):
    return f'{x * 1e6:.0f}'

def to_micro_asins(x, pos):
    return f'{x * 1e6:.2f}'

ax.xaxis.set_major_formatter(ticker.FuncFormatter(to_micro))
ax.set_xlabel(r"Dark photon mass [$\rm \mu eV$]")
axins.xaxis.set_major_formatter(ticker.FuncFormatter(to_micro_asins))
axins.tick_params(axis='both', which='major', width=1.4, length=8)
axins.tick_params(axis='both', which='minor', width=1.0, length=4)
# plt.rcParams['font.family']= 'sans-serif'
# plt.rcParams['font.sans-serif'] = ['Arial']
# #plt.rcParams['mathtext.fontset'] = 'cm' # Computer Modern (TeXのフォント)
# plt.rcParams['font.size'] = 16 # 論文なら10-12ptくらいが適正
# 軸目盛りがうるさい場合は消す
#axins.tick_params(labelleft=False, labelbottom=False, length=3)

# ズーム領域をメイン図上に矩形で示したい場合：
# from matplotlib.patches import Rectangle
# rect = Rectangle((x1, y1), x2-x1, y2_-y1,
#                  linewidth=1, edgecolor='red', facecolor='none')
# ax.add_patch(rect)
# もしくは mark_inset で線を引く場合：
#mark_inset(ax, axins, loc1=2, loc2=4, fc="none", ec="blue", lw=1)


MySaveFig(fig,'DarkPhoton_DarQ-Lamb2024')
